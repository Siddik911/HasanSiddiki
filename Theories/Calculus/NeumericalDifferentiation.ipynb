# %% [markdown]
# One way of thinking numerical differentiation is to approximate the differentiation of a function.
#
# $\frac{dx}{dt} \approx \frac{x(t + \Delta t) - x(t)}{\Delta t}$
#
# $x(t+ \Delta t) \approx x(t) + \Delta t f(t)$
